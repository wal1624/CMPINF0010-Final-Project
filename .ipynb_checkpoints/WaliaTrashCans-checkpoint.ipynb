# %% [markdown]
# # Smart Trash Cans
# We'll be looking at a dataset that contains hundreds of smart trash cans in different neighborhoods accross Pittsburgh, in order to see which neighborhood has the most amount of smart trash cans.
#
# The smart trash cans, that the city of Pittsburgh has employed, have built in sensors that detect how full it is. This innovation allows the labor force in Pittsburgh to not have to waste as much time on emptying trash can, and they can use that time to tidy up their respective areas. "'Based on our analysis, we expect that the smart litter cans will give us the ability to make process improvements that will reduce the amount of labor hours spent on emptying garbage cans by at least half,' said Matt Jacob, the project manager for the program for the Department of Innovation and Performance. 'As a result, DPW will be able to reallocate those resources to other tasks.'" (From source: https://pittsburghpa.gov/press-releases/press-releases.html?id=2986).

# %% [markdown]
# # Dataset:
# My dataset is from [WPRDC](https://data.wprdc.org/dataset/smart-trash-containers). By itself, the CSV contains several columns that do not suit my purpose (container id, assignment date, and so forth); so I decided to group it by the neighborhoods and focus on the amount of trash cans for each neighborhood.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# Read csv file and create it into a dataframe
SmartTCans = pd.read_csv("SmartTCansNew.csv")
num_cans = pd.DataFrame(SmartTCans[["neighborhood", "Number of Cans"]])
num_cans
# Out:
#               neighborhood  Number of Cans
# 0        Central Northside               1
# 1        Central Northside               1
# 2         Allegheny Center               1
# 3        Central Northside               1
# 4     California-Kirkbride               1
# ...                    ...             ...
# 1204               Larimer               1
# 1205               Larimer               1
# 1206               Larimer               1
# 1207               Larimer               1
# 1208               Larimer               1
#
# [1209 rows x 2 columns]

# %% [markdown]
# As you can see, by itself, this data doesn't help us in any way as I can only see one trash can next to each entry for each neighborhood. So, I'm going to use groupby and sum all of the trash cans for each unique neighborhood in order to see how many trash cans belong to each neighborhood.

# %%
# Group the csv by neighbohood and sum up all of the trashcans by neighborhood
num_cans = pd.DataFrame(num_cans.groupby("neighborhood").sum())
#Add column name
num_cans = num_cans.reset_index().sort_values(by="Number of Cans", ascending=False)
num_cans
# Out:
#            neighborhood  Number of Cans
# 57            Shadyside              77
# 25         East Liberty              68
# 66  Squirrel Hill South              64
# 8            Bloomfield              59
# 61     South Side Flats              56
# ..                  ...             ...
# 23        East Carnegie               1
# 60          South Shore               1
# 46           Mt. Oliver               1
# 49    Northview Heights               1
# 78              Windgap               1
#
# [79 rows x 2 columns]

# %% [markdown]
# As you can see, Shadyside has the most smart trash cans while several others have only one. However, this can mapped onto a map of Pittsburgh to show more accurately the concentration of smart trash cans to give us better context.

# %%
# Import geopandas and create a neighborhoods file
import geopandas
neighborhoods = geopandas.read_file("Neighborhoods/Neighborhoods_.shp")

# %%
cans_map = neighborhoods.merge(num_cans, how='left', left_on='hood', right_on='neighborhood')

# %% [markdown]
# A bunch of useless data from cans_map, so let me show it to you in the form of a map!

# %%
# Plots the concentration of trash cans
cans_map.plot(column='Number of Cans', # set the data to be used for coloring
               cmap='YlGn',              # choose a color palette
               edgecolor="white",        # outline the districts in white
               legend=True,              # show the legend
               legend_kwds={'label': "Number of Smart Trash Cans"}, # label the legend
               figsize=(15, 10),         # set the size
               missing_kwds={"color": "lightgrey"} # set districts with no data to gray
               )

# %% [markdown]
# # Analysis
# It seems that ShadySide had the most smart trash cans with 77; whereas, neighborhoods such as East Carnegie and Mt. Oliver have 1 smart trash can total. Now, judging by the map, Shadyside has one of the most area out all of the other neighborhoods, and so it makes sense that Shadyside will have the most smart trash cans. However, this works to its advantage as to cover and maintain this large area the labor force musn't have to unncessarily waste their time emptying many trash cans. So, the use of smart trash cans allows them to spend more time tidying Shadyside. Nevertheless, in order to make a more accurate judgement, we should look at how the size of each neighborhood compares to the number of trash cans within that neighborhood.

# %%
#Reading in new data for acres
hood_data = pd.read_csv("Neighborhood data.csv")
#Getting acres
hood_data = hood_data[['hood', 'acres']]

# %% [markdown]
# Now, I kept running into an error when trying to create a map for the trash can percentage; basically, my trash can percentage is created from dividing the number of cans by the acres (and multiplied by 100 for readability), but my map showed weird data points, as the data points it showed were much smaller than the actual trash can percentages. And, it kept showing an error of  dividing, which, from further research, indicates that one of percentages had a denominator of 0 (dividing by zero). So, one of my acres data points had to be zero, and upon further inspection I found Perry North had the incorrect acreage of 0. So, after googling what the actual acreage of it was (775.68), I used iloc (it has an index of 17) to convert that 0 to 775.68. So, my map is now successfully able to be created.

# %%
# Change Perry North acreage to 775.68
hood_data.iloc[[17],[1]] = 775.68
# Merge num_cans and acreage
total_data = num_cans.merge(hood_data, how='left', left_on='neighborhood', right_on='hood')
# Make the trash can percentage
total_data['Trash can percentage'] = (total_data['Number of Cans'] / total_data['acres']) * 100
total_data.sort_values(by="Trash can percentage", ascending=False)

# %% [markdown]
# As you can see, North Shore has the highest trash can percentage, which honestly I did not expect because I thought that the amount of trash cans that Shadyside has would be enough to make it have the highest percentage. Now, let's see this data mapped on a map of Pittsburgh!

# %%
#Create new map and plot it
total_map = neighborhoods.merge(total_data, how='left', left_on='hood', right_on='hood')

total_map.plot(column='Trash can percentage', # set the data to be used for coloring
               cmap='YlGn',              # choose a color palette
               edgecolor="white",        # outline the districts in white
               legend=True,              # show the legend
               legend_kwds={'label': "Percentage of Smart Trash Cans"}, # label the legend
               figsize=(15, 10),         # set the size
               missing_kwds={"color": "lightgrey"} # set districts with no data to gray
               )

# %%
# Trash can percentage for Shadyside (0 for number of cans data and 4 for the column of trash can percentage)
total_data.iloc[[0],[4]]
# Out:
#    Trash can percentage
# 0             13.004472

# %% [markdown]
# # Final Analysis
# So, North Shore is the most green in terms of having the most trash cans in comparison to its acres; whereas, Shadyside is now middle of the pack with a percentage of 13. Now, this makes sense as North Shore is relatively small, yet has a lot of smart trash cans which shows that this neighborhood is trying to be environmentally consious. Thereby, North Shore is the best neighborhood to live in according to my data.
